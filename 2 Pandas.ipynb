# %%
import pandas as pd

# %%
titanic = pd.read_csv('https://raw.githubusercontent.com/zekelabs/machine-learning-for-beginners/master/data/titanic-train.csv', chunksize=100)

# %%
cnt = 0
for d in titanic:
    cnt += 1
    #print (d.count())
    #print ('---')
    if (cnt == 5):
        df = d

# %%
movie = pd.read_json('https://raw.githubusercontent.com/zekelabs/machine-learning-for-beginners/master/movie.json.txt')

# %%
movie
# Out:
#                Adam Cohen  Bill Duffy  Brenda Peterson  Chris Duncan  \
# Goodfellas            4.5         4.5              2.0           NaN
# Raging Bull           NaN         NaN              1.0           4.5
# Roman Holiday         3.0         NaN              4.5           NaN
# Scarface              3.0         5.0              1.5           NaN
# The Apartment         1.0         1.0              5.0           1.5
# Vertigo               3.5         4.5              3.0           NaN
#
#                Clarissa Jackson  David Smith  Julie Hammel  Samuel Miller
# Goodfellas                  2.5          4.5           3.0            5.0
# Raging Bull                 4.0          3.0           NaN            5.0
# Roman Holiday               1.5          NaN           4.5            1.0
# Scarface                    4.5          4.5           2.5            3.5
# The Apartment               1.0          1.0           NaN            1.0
# ...

# %%
movie.loc['Scarface':'Vertigo']
# Out:
#                Adam Cohen  Bill Duffy  Brenda Peterson  Chris Duncan  \
# Scarface              3.0         5.0              1.5           NaN
# The Apartment         1.0         1.0              5.0           1.5
# Vertigo               3.5         4.5              3.0           NaN
#
#                Clarissa Jackson  David Smith  Julie Hammel  Samuel Miller
# Scarface                    4.5          4.5           2.5            3.5
# The Apartment               1.0          1.0           NaN            1.0
# Vertigo                     5.0          4.0           NaN            NaN

# %%
movie.iloc[1:3]
# Out:
#                Adam Cohen  Bill Duffy  Brenda Peterson  Chris Duncan  \
# Raging Bull           NaN         NaN              1.0           4.5
# Roman Holiday         3.0         NaN              4.5           NaN
#
#                Clarissa Jackson  David Smith  Julie Hammel  Samuel Miller
# Raging Bull                 4.0          3.0           NaN            5.0
# Roman Holiday               1.5          NaN           4.5            1.0

# %%
import json

# %%
with open('j.json') as json_data:
    data = json.load(json_data)

# %%
# Out:
# {'counties': [{'name': 'Dade', 'population': 12345},
#   {'name': 'Palm Beach', 'population': 60000}],
#  'info': {'governor': 'Rick Scott'},
#  'shortname': 'FL',
#  'state': 'Florida'}

# %%
from pandas.io.json import json_normalize

# %%
df = json_normalize(data,'counties',['state','shortname',['info','governor']])

# %%
df.to_csv('out.csv')

# %%
df
# Out:
#          name  population    state shortname info.governor
# 0        Dade       12345  Florida        FL    Rick Scott
# 1  Palm Beach       60000  Florida        FL    Rick Scott

# %%
df
# Out:
#          name  population    state shortname info.governor
# 0        Dade       12345  Florida        FL    Rick Scott
# 1  Palm Beach       60000  Florida        FL    Rick Scott

# %%
titanic = pd.read_csv('https://raw.githubusercontent.com/zekelabs/machine-learning-for-beginners/master/data/titanic-train.csv')

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
titanic.Age.fillna(titanic.Age.mean(), inplace=True)

# %%
import numpy as np

# %%
titanic['sts'] = np.where(titanic['Age']>18,'Adult','Child')

# %%
def f(x):
    ...
titanic['status'] = titanic.Age.map(f)

# %%
df = pd.DataFrame({'A':[1,2,3,4,5,6],
              'B':[5,6,7,8,8,9],
              'C':[3,4,2,1,4,5]})

# %%
df
# Out:
#    A  B  C
# 0  1  5  3
# 1  2  6  4
# 2  3  7  2
# 3  4  8  1
# 4  5  8  4
# 5  6  9  5

# %%
df.apply(lambda x:sum(x),axis=1)
# Out:
# 0     9
# 1    12
# 2    12
# 3    13
# 4    17
# 5    20
# dtype: int64

# %%
def f(r):
    return sum(r[r%2 !=0])

df.apply(f,axis=1)
# Out:
# 0     9
# 1     0
# 2    10
# 3     1
# 4     5
# 5    14
# dtype: int64

# %%
a = pd.Series([1,2,3,4])

# %%
a[a % 2 != 0]
# Out:
# 0    1
# 2    3
# dtype: int64

# %%
titanic.groupby(['Sex','Pclass','Survived']).describe()
# Out:
#                           Age                                          \
#                         count       mean        std    min        25%
# Sex    Pclass Survived
# female 1      0           3.0  25.666667  24.006943   2.00  13.500000
#               1          91.0  34.420792  12.642681  14.00  24.000000
#        2      0           6.0  36.000000  12.915107  24.00  26.250000
#               1          70.0  28.127118  12.581268   2.00  22.000000
#        3      0          72.0  25.206736  11.471220   2.00  18.000000
#               1          72.0  22.930249  11.080836   0.75  16.750000
# male   1      0          77.0  41.489427  14.211358  18.00  29.699118
#               1          45.0  35.520346  14.215676   0.92  28.000000
#        2      0          91.0  33.086745  11.717075  16.00  25.000000
#               1          17.0  17.631073  18.840401   0.67   1.000000
#        3      0         300.0  27.948083  10.325891   1.00  22.000000
# ...
